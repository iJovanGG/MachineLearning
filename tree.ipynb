# %%
import os 
import tarfile 
import urllib

# Array math
import numpy as np 

# Inspecting functions
import inspect

import time

# Ploting 
import seaborn as sns
import matplotlib.pyplot as plt

# Importing the custom written class 
from DecisionTree import Node 

# Importing the scikit-learn tree implementation
from sklearn.tree import DecisionTreeClassifier

import pandas as pd

csv_path=os.path.join("https://raw.githubusercontent.com/iJovanGG/MachineLearning/master/datasets/income/", "adult.csv")

tree = pd.read_csv(csv_path)
tree.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country yearly-income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K
# 2             0             0              40  United-States         <=50K
# 3             0             0              40  United-States         <=50K
# 4             0             0              40           Cuba         <=50K

# %%
tree.sample(10)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 6375    50  Self-emp-not-inc  105010       HS-grad              9
# 20457   60           Private  308608       HS-grad              9
# 5541    33           Private  158416       HS-grad              9
# 11137   51           Private  174754       HS-grad              9
# 1576    38  Self-emp-not-inc  257250       HS-grad              9
# 5653    50           Private   96586     Assoc-voc             11
# 15201   62           Private  238913  Some-college             10
# 11832   34           Private  339142       HS-grad              9
# 20324   65           Private  213477       Masters             14
# 514     28           Private  189346       HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 6375   Married-civ-spouse    Farming-fishing        Husband  White    Male
# 20457  Married-civ-spouse              Sales        Husband  White    Male
# 5541        Never-married  Machine-op-inspct  Not-in-family  White    Male
# 11137       Never-married      Other-service  Not-in-family  Black  Female
# 1576        Never-married    Farming-fishing  Not-in-family  White    Male
# 5653   Married-civ-spouse      Other-service        Husband  White    Male
# 15201  Married-civ-spouse       Tech-support        Husband  White    Male
# 11832           Separated  Handlers-cleaners      Unmarried  White  Female
# 20324            Divorced              Sales  Not-in-family  White    Male
# 514              Divorced       Craft-repair  Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country yearly-income
# 6375              0          2051              20  United-States         <=50K
# 20457             0             0              50  United-States         <=50K
# 5541              0             0              40  United-States         <=50K
# 11137             0             0              38  United-States         <=50K
# 1576              0             0              52  United-States         <=50K
# 5653              0             0              40  United-States         <=50K
# 15201          2829             0              24  United-States         <=50K
# 11832             0             0              40  United-States         <=50K
# 20324             0             0              28  United-States         <=50K
# 514               0             0              45  United-States         <=50K

# %%
dtree = tree[['yearly-income', 'education', 'workclass', 'sex', 'age', 'hours-per-week']].copy()

# Droping missing entries
dtree.dropna(inplace=True)

# %%
print(f"Number of observations: {dtree.shape[0]}")
# Out:
# Number of observations: 32561

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(y='age', x='hours-per-week', data=dtree, hue='yearly-income')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.scatterplot(y='sex', x='hours-per-week', data=dtree, hue='yearly-income')
plt.grid()
plt.show()

# %%
# Define the split value 
age_split = 40

# Ploting the original plot
plt.figure(figsize=(10, 10))
sns.scatterplot(y='hours-per-week', x='age', data=dtree, hue='yearly-income')
plt.grid()

# Adding the vertical line
plt.axvline(age_split, label='Spliting criteria', color='red')
plt.legend()
plt.show()

# %%
# Getting the left and right datasets
left = dtree[dtree['age']<=age_split]
right = dtree[dtree['age']>age_split]

# %%
print(f"Observations to the left of criteria: {left.shape[0]}")
print(f"Observations to the right of criteria: {right.shape[0]}")
# Out:
# Observations to the left of criteria: 19118
# Observations to the right of criteria: 13443

# %%
left.groupby('yearly-income', as_index=False).size()
# Out:
#   yearly-income   size
# 0         <=50K  16030
# 1          >50K   3088

# %%
right.groupby('yearly-income', as_index=False).size()
# Out:
#   yearly-income  size
# 0         <=50K  8690
# 1          >50K  4753

# %%
print(inspect.getsource(Node.GINI_impurity))
# Out:
#     @staticmethod
#     def GINI_impurity(y1_count: int, y2_count: int) -> float:
#         """
#         Given the observations of a binary class calculate the GINI impurity
#         """
#         # Ensuring the correct types
#         if y1_count is None:
#             y1_count = 0
#
#         if y2_count is None:
#             y2_count = 0
#
#         # Getting the total observations
#         n = y1_count + y2_count
#
#         # If n is 0 then we return the lowest possible gini impurity
#         if n == 0:
#             return 0.0
#
#         # Getting the probability to see each of the classes
#         p1 = y1_count / n
#         p2 = y2_count / n
#
#         # Calculating GINI
#         gini = 1 - (p1 ** 2 + p2 ** 2)
#
#         # Returning the gini impurity
#         return gini

# %%
left_counts = left.groupby("yearly-income").size().values.tolist()
right_counts = right.groupby("yearly-income").size().values.tolist()

gini_left = Node.GINI_impurity(left_counts[0], left_counts[1])
gini_right = Node.GINI_impurity(right_counts[0], right_counts[1])

# %%
print(f"Gini impurity of the left node: {gini_left}")
print(f"Gini impurity of the right node: {gini_right}")
# Out:
# Gini impurity of the left node: 0.2708668736515176
# Gini impurity of the right node: 0.45711470156401446

# %%
w1 = left.shape[0]/ (left.shape[0] + right.shape[0]) 
w2 = right.shape[0] / (left.shape[0] + right.shape[0])

# %%
gini_final = w1 * gini_left + w2 * gini_right

# %%
print(f"Final gini impurity: {gini_final}")
# Out:
# Final gini impurity: 0.3477603827767808

# %%
def GINI_impurity_df(df:pd.DataFrame, target):
    """
    Function to calculate the resulting GINI impurity of a split
    """
    # Getting the counts and ginis
    counts = df.groupby(target).size().values.tolist()

    gini = Node.GINI_impurity(counts[0], counts[1])
    
    return gini

# %%
gini_orig = GINI_impurity_df(dtree, 'yearly-income')

# %%
print(f"Gini non-splited: {gini_orig}")
print(f"Gini with the proposed split: {gini_final}")
print(f"Gini gain: {gini_orig - gini_final}")
# Out:
# Gini non-splited: 0.3656406289773486
# Gini with the proposed split: 0.3477603827767808
# Gini gain: 0.01788024620056783

# %%
print(inspect.getsource(Node.ma))
# Out:
#     @staticmethod
#     def ma(x: np.array, window: int) -> np.array:
#         """
#         Calculates the moving average of the given list.
#         """
#         return np.convolve(x, np.ones(window), 'valid') / window

# %%
print(inspect.getsource(Node.best_split))
# Out:
#     def best_split(self) -> tuple:
#         """
#         Given the X features and Y targets calculates the best split
#         for a decision tree
#         """
#         # Creating a dataset for spliting
#         df = self.X.copy()
#         df['Y'] = self.Y
#
#         # Getting the GINI impurity for the base input
#         GINI_base = self.get_GINI()
#
#         # Finding which split yields the best GINI gain
#         max_gain = 0
#
#         # Default best feature and split
#         best_feature = None
#         best_value = None
#
#         for feature in self.features:
#             # Droping missing values
#             Xdf = df.dropna().sort_values(feature)
#
#             # Sorting the values and getting the rolling average
#             xmeans = self.ma(Xdf[feature].unique(), 2)
#
#             for value in xmeans:
#                 # Spliting the dataset
#                 left_counts = Counter(Xdf[Xdf[feature]<value]['Y'])
#                 right_counts = Counter(Xdf[Xdf[feature]>=value]['Y'])
#
#                 # Getting the Y distribution from the dicts
#                 y0_left, y1_left, y0_right, y1_right = left_counts.get(0, 0), left_counts.get(1, 0), right_counts.get(0, 0), right_counts.get(1, 0)
#
#                 # Getting the left and right gini impurities
#                 gini_left = self.GINI_impurity(y0_left, y1_left)
#                 gini_right = self.GINI_impurity(y0_right, y1_right)
#
#                 # Getting the obs count from the left and the right data splits
#                 n_left = y0_left + y1_left
#                 n_right = y0_right + y1_right
#
#                 # Calculating the weights for each of the nodes
#                 w_left = n_left / (n_left + n_right)
#                 w_right = n_right / (n_left + n_right)
#
#                 # Calculating the weighted GINI impurity
#                 wGINI = w_left * gini_left + w_right * gini_right
#
#                 # Calculating the GINI gain
#                 GINIgain = GINI_base - wGINI
#
#                 # Checking if this is the best split so far
#                 if GINIgain > max_gain:
#                     best_feature = feature
#                     best_value = value
#
#                     # Setting the best gain to the current one
#                     max_gain = GINIgain
#
#         return (best_feature, best_value)

# %%
# Dropping missing values
ddtree = tree[['yearly-income', 'age', 'hours-per-week']].dropna().copy()
ddtree['yearly-income']=ddtree['yearly-income'].replace('>50K','1')
ddtree['yearly-income']=ddtree['yearly-income'].replace('<=50K','0')
ddtree['yearly-income']=ddtree['yearly-income'].astype('int')
# Defining the X and Y matrices
Y = ddtree['yearly-income'].values
print(Y)

X = ddtree[['age', 'hours-per-week']]
print(X)

# Saving the feature list 
features = list(X.columns)
# Out:
# [0 0 0 ... 0 0 1]
#        age  hours-per-week
# 0       39              40
# 1       50              13
# 2       38              40
# 3       53              40
# 4       28              40
# ...    ...             ...
# 32556   27              38
# 32557   40              40
# 32558   58              40
# 32559   22              20
# 32560   52              40
#
# [32561 rows x 2 columns]

# %%
# Setting the available hyper parameters of a tree
hp = {
    'max_depth': 10,
    'min_samples_split': 5
}
print(hp)
# Out:
# {'max_depth': 10, 'min_samples_split': 5}

# %%
# Initiating the Node
root = Node(Y, X, **hp)

# Getting teh best split
root.grow_tree()

# Printing the tree information 
root.print_tree()
# Out:
# Root
#    | GINI impurity of the node: 0.37
#    | Class distribution in the node: {0: 24720, 1: 7841}
#    | Predicted class: 0
# |-------- Split rule: age <= 29.5
#            | GINI impurity of the node: 0.1
#            | Class distribution in the node: {0: 9200, 1: 511}
#            | Predicted class: 0
# |---------------- Split rule: age <= 25.5
#                    | GINI impurity of the node: 0.03
#                    | Class distribution in the node: {0: 6297, 1: 114}
#                    | Predicted class: 0
# |------------------------ Split rule: age <= 23.5
#                            | GINI impurity of the node: 0.01
#                            | Class distribution in the node: {0: 4742, 1: 30}
#                            | Predicted class: 0
# |-------------------------------- Split rule: hours-per-week <= 45.5
#                                    | GINI impurity of the node: 0.01
#                                    | Class distribution in the node: {0: 4405, 1: 18}
#                                    | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week <= 39.5
#                                            | GINI impurity of the node: 0.0
#                                            | Class distribution in the node: {0: 2607, 1: 1}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week <= 31.0
#                                                    | GINI impurity of the node: 0.0
#                                                    | Class distribution in the node: {0: 2166}
#                                                    | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week > 31.0
#                                                    | GINI impurity of the node: 0.0
#                                                    | Class distribution in the node: {0: 441, 1: 1}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 32.5
#                                                            | GINI impurity of the node: 0.04
#                                                            | Class distribution in the node: {0: 50, 1: 1}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 21.5
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 34}
#                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 21.5
#                                                                    | GINI impurity of the node: 0.11
#                                                                    | Class distribution in the node: {0: 16, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 22.5
#                                                                            | GINI impurity of the node: 0.32
#                                                                            | Class distribution in the node: {0: 4, 1: 1}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 22.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 12}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week > 32.5
#                                                            | GINI impurity of the node: 0.0
#                                                            | Class distribution in the node: {0: 391}
#                                                            | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week > 39.5
#                                            | GINI impurity of the node: 0.02
#                                            | Class distribution in the node: {0: 1798, 1: 17}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: age <= 21.5
#                                                    | GINI impurity of the node: 0.01
#                                                    | Class distribution in the node: {0: 993, 1: 3}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age <= 20.5
#                                                            | GINI impurity of the node: 0.0
#                                                            | Class distribution in the node: {0: 670, 1: 1}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 19.5
#                                                                    | GINI impurity of the node: 0.01
#                                                                    | Class distribution in the node: {0: 367, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 18.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 159}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 18.5
#                                                                            | GINI impurity of the node: 0.01
#                                                                            | Class distribution in the node: {0: 208, 1: 1}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 41.0
#                                                                                    | GINI impurity of the node: 0.01
#                                                                                    | Class distribution in the node: {0: 191, 1: 1}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 41.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 17}
#                                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 19.5
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 303}
#                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age > 20.5
#                                                            | GINI impurity of the node: 0.01
#                                                            | Class distribution in the node: {0: 323, 1: 2}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 41.0
#                                                                    | GINI impurity of the node: 0.01
#                                                                    | Class distribution in the node: {0: 300, 1: 2}
#                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 41.0
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 23}
#                                                                    | Predicted class: 0
# |------------------------------------------------ Split rule: age > 21.5
#                                                    | GINI impurity of the node: 0.03
#                                                    | Class distribution in the node: {0: 805, 1: 14}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 40.5
#                                                            | GINI impurity of the node: 0.04
#                                                            | Class distribution in the node: {0: 743, 1: 14}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 22.5
#                                                                    | GINI impurity of the node: 0.04
#                                                                    | Class distribution in the node: {0: 323, 1: 6}
#                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 22.5
#                                                                    | GINI impurity of the node: 0.04
#                                                                    | Class distribution in the node: {0: 420, 1: 8}
#                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week > 40.5
#                                                            | GINI impurity of the node: 0.0
#                                                            | Class distribution in the node: {0: 62}
#                                                            | Predicted class: 0
# |-------------------------------- Split rule: hours-per-week > 45.5
#                                    | GINI impurity of the node: 0.07
#                                    | Class distribution in the node: {0: 337, 1: 12}
#                                    | Predicted class: 0
# |---------------------------------------- Split rule: age <= 21.5
#                                            | GINI impurity of the node: 0.02
#                                            | Class distribution in the node: {0: 168, 1: 2}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week <= 46.5
#                                                    | GINI impurity of the node: 0.44
#                                                    | Class distribution in the node: {1: 1, 0: 2}
#                                                    | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week > 46.5
#                                                    | GINI impurity of the node: 0.01
#                                                    | Class distribution in the node: {0: 166, 1: 1}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 59.0
#                                                            | GINI impurity of the node: 0.0
#                                                            | Class distribution in the node: {0: 111}
#                                                            | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week > 59.0
#                                                            | GINI impurity of the node: 0.04
#                                                            | Class distribution in the node: {0: 55, 1: 1}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 19.5
#                                                                    | GINI impurity of the node: 0.08
#                                                                    | Class distribution in the node: {0: 23, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 18.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 8}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 18.5
#                                                                            | GINI impurity of the node: 0.12
#                                                                            | Class distribution in the node: {0: 15, 1: 1}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 63.0
#                                                                                    | GINI impurity of the node: 0.17
#                                                                                    | Class distribution in the node: {0: 10, 1: 1}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 63.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 5}
#                                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 19.5
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 32}
#                                                                    | Predicted class: 0
# |---------------------------------------- Split rule: age > 21.5
#                                            | GINI impurity of the node: 0.11
#                                            | Class distribution in the node: {0: 169, 1: 10}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week <= 54.5
#                                                    | GINI impurity of the node: 0.08
#                                                    | Class distribution in the node: {0: 98, 1: 4}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age <= 22.5
#                                                            | GINI impurity of the node: 0.12
#                                                            | Class distribution in the node: {0: 43, 1: 3}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 49.0
#                                                                    | GINI impurity of the node: 0.18
#                                                                    | Class distribution in the node: {0: 9, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 47.0
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 1}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 47.0
#                                                                            | GINI impurity of the node: 0.2
#                                                                            | Class distribution in the node: {0: 8, 1: 1}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 49.0
#                                                                    | GINI impurity of the node: 0.1
#                                                                    | Class distribution in the node: {0: 34, 1: 2}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 51.5
#                                                                            | GINI impurity of the node: 0.11
#                                                                            | Class distribution in the node: {0: 32, 1: 2}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 51.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 2}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------- Split rule: age > 22.5
#                                                            | GINI impurity of the node: 0.04
#                                                            | Class distribution in the node: {0: 55, 1: 1}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 49.0
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 12}
#                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 49.0
#                                                                    | GINI impurity of the node: 0.04
#                                                                    | Class distribution in the node: {0: 43, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 51.0
#                                                                            | GINI impurity of the node: 0.05
#                                                                            | Class distribution in the node: {0: 40, 1: 1}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 51.0
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 3}
#                                                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week > 54.5
#                                                    | GINI impurity of the node: 0.14
#                                                    | Class distribution in the node: {0: 71, 1: 6}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 55.5
#                                                            | GINI impurity of the node: 0.24
#                                                            | Class distribution in the node: {0: 19, 1: 3}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 22.5
#                                                                    | GINI impurity of the node: 0.28
#                                                                    | Class distribution in the node: {0: 10, 1: 2}
#                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 22.5
#                                                                    | GINI impurity of the node: 0.18
#                                                                    | Class distribution in the node: {0: 9, 1: 1}
#                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week > 55.5
#                                                            | GINI impurity of the node: 0.1
#                                                            | Class distribution in the node: {0: 52, 1: 3}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 71.0
#                                                                    | GINI impurity of the node: 0.13
#                                                                    | Class distribution in the node: {0: 40, 1: 3}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 68.0
#                                                                            | GINI impurity of the node: 0.1
#                                                                            | Class distribution in the node: {0: 37, 1: 2}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: age <= 22.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 11}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: age > 22.5
#                                                                                    | GINI impurity of the node: 0.13
#                                                                                    | Class distribution in the node: {0: 26, 1: 2}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 68.0
#                                                                            | GINI impurity of the node: 0.38
#                                                                            | Class distribution in the node: {0: 3, 1: 1}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 71.0
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 12}
#                                                                    | Predicted class: 0
# |------------------------ Split rule: age > 23.5
#                            | GINI impurity of the node: 0.1
#                            | Class distribution in the node: {0: 1555, 1: 84}
#                            | Predicted class: 0
# |-------------------------------- Split rule: hours-per-week <= 43.5
#                                    | GINI impurity of the node: 0.07
#                                    | Class distribution in the node: {0: 1261, 1: 44}
#                                    | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week <= 25.5
#                                            | GINI impurity of the node: 0.0
#                                            | Class distribution in the node: {0: 169}
#                                            | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week > 25.5
#                                            | GINI impurity of the node: 0.07
#                                            | Class distribution in the node: {0: 1092, 1: 44}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week <= 26.5
#                                                    | GINI impurity of the node: 0.5
#                                                    | Class distribution in the node: {1: 1, 0: 1}
#                                                    | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week > 26.5
#                                                    | GINI impurity of the node: 0.07
#                                                    | Class distribution in the node: {0: 1091, 1: 43}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age <= 24.5
#                                                            | GINI impurity of the node: 0.05
#                                                            | Class distribution in the node: {0: 518, 1: 13}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 31.0
#                                                                    | GINI impurity of the node: 0.08
#                                                                    | Class distribution in the node: {0: 48, 1: 2}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 28.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 1}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 28.5
#                                                                            | GINI impurity of the node: 0.08
#                                                                            | Class distribution in the node: {0: 47, 1: 2}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 31.0
#                                                                    | GINI impurity of the node: 0.04
#                                                                    | Class distribution in the node: {0: 470, 1: 11}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 39.5
#                                                                            | GINI impurity of the node: 0.03
#                                                                            | Class distribution in the node: {0: 66, 1: 1}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 35.5
#                                                                                    | GINI impurity of the node: 0.05
#                                                                                    | Class distribution in the node: {0: 41, 1: 1}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 35.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 25}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 39.5
#                                                                            | GINI impurity of the node: 0.05
#                                                                            | Class distribution in the node: {0: 404, 1: 10}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 41.0
#                                                                                    | GINI impurity of the node: 0.05
#                                                                                    | Class distribution in the node: {0: 398, 1: 10}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 41.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 6}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age > 24.5
#                                                            | GINI impurity of the node: 0.09
#                                                            | Class distribution in the node: {0: 573, 1: 30}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 34.5
#                                                                    | GINI impurity of the node: 0.04
#                                                                    | Class distribution in the node: {0: 43, 1: 1}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 30.5
#                                                                            | GINI impurity of the node: 0.05
#                                                                            | Class distribution in the node: {0: 35, 1: 1}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 29.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 3}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 29.0
#                                                                                    | GINI impurity of the node: 0.06
#                                                                                    | Class distribution in the node: {0: 32, 1: 1}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 30.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 8}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 34.5
#                                                                    | GINI impurity of the node: 0.1
#                                                                    | Class distribution in the node: {0: 530, 1: 29}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 39.0
#                                                                            | GINI impurity of the node: 0.13
#                                                                            | Class distribution in the node: {0: 65, 1: 5}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 35.5
#                                                                                    | GINI impurity of the node: 0.09
#                                                                                    | Class distribution in the node: {0: 41, 1: 2}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 35.5
#                                                                                    | GINI impurity of the node: 0.2
#                                                                                    | Class distribution in the node: {0: 24, 1: 3}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 39.0
#                                                                            | GINI impurity of the node: 0.09
#                                                                            | Class distribution in the node: {0: 465, 1: 24}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 42.5
#                                                                                    | GINI impurity of the node: 0.09
#                                                                                    | Class distribution in the node: {0: 458, 1: 24}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 42.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 7}
#                                                                                    | Predicted class: 0
# |-------------------------------- Split rule: hours-per-week > 43.5
#                                    | GINI impurity of the node: 0.21
#                                    | Class distribution in the node: {0: 294, 1: 40}
#                                    | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week <= 44.5
#                                            | GINI impurity of the node: 0.42
#                                            | Class distribution in the node: {1: 3, 0: 7}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: age <= 24.5
#                                                    | GINI impurity of the node: 0.32
#                                                    | Class distribution in the node: {0: 4, 1: 1}
#                                                    | Predicted class: 0
# |------------------------------------------------ Split rule: age > 24.5
#                                                    | GINI impurity of the node: 0.48
#                                                    | Class distribution in the node: {1: 2, 0: 3}
#                                                    | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week > 44.5
#                                            | GINI impurity of the node: 0.2
#                                            | Class distribution in the node: {0: 287, 1: 37}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week <= 68.0
#                                                    | GINI impurity of the node: 0.19
#                                                    | Class distribution in the node: {0: 268, 1: 32}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 62.5
#                                                            | GINI impurity of the node: 0.2
#                                                            | Class distribution in the node: {0: 256, 1: 32}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 24.5
#                                                                    | GINI impurity of the node: 0.18
#                                                                    | Class distribution in the node: {0: 135, 1: 15}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 51.0
#                                                                            | GINI impurity of the node: 0.2
#                                                                            | Class distribution in the node: {0: 105, 1: 13}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 48.5
#                                                                                    | GINI impurity of the node: 0.17
#                                                                                    | Class distribution in the node: {1: 5, 0: 47}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 48.5
#                                                                                    | GINI impurity of the node: 0.21
#                                                                                    | Class distribution in the node: {0: 58, 1: 8}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 51.0
#                                                                            | GINI impurity of the node: 0.12
#                                                                            | Class distribution in the node: {0: 30, 1: 2}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 54.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 3}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 54.5
#                                                                                    | GINI impurity of the node: 0.13
#                                                                                    | Class distribution in the node: {0: 27, 1: 2}
#                                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 24.5
#                                                                    | GINI impurity of the node: 0.22
#                                                                    | Class distribution in the node: {1: 17, 0: 121}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 55.5
#                                                                            | GINI impurity of the node: 0.19
#                                                                            | Class distribution in the node: {1: 12, 0: 100}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 45.5
#                                                                                    | GINI impurity of the node: 0.21
#                                                                                    | Class distribution in the node: {0: 36, 1: 5}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 45.5
#                                                                                    | GINI impurity of the node: 0.18
#                                                                                    | Class distribution in the node: {1: 7, 0: 64}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 55.5
#                                                                            | GINI impurity of the node: 0.31
#                                                                            | Class distribution in the node: {0: 21, 1: 5}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 58.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {1: 1}
#                                                                                    | Predicted class: 1
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 58.0
#                                                                                    | GINI impurity of the node: 0.27
#                                                                                    | Class distribution in the node: {0: 21, 1: 4}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week > 62.5
#                                                            | GINI impurity of the node: 0.0
#                                                            | Class distribution in the node: {0: 12}
#                                                            | Predicted class: 0
# |------------------------------------------------ Split rule: hours-per-week > 68.0
#                                                    | GINI impurity of the node: 0.33
#                                                    | Class distribution in the node: {1: 5, 0: 19}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 73.5
#                                                            | GINI impurity of the node: 0.48
#                                                            | Class distribution in the node: {1: 2, 0: 3}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 24.5
#                                                                    | GINI impurity of the node: 0.44
#                                                                    | Class distribution in the node: {1: 2, 0: 1}
#                                                                    | Predicted class: 1
# |---------------------------------------------------------------- Split rule: age > 24.5
# ...
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: age > 63.0
#                                                                                    | GINI impurity of the node: 0.44
#                                                                                    | Class distribution in the node: {0: 4, 1: 2}
#                                                                                    | Predicted class: 0
# |---------------------------------------- Split rule: hours-per-week > 65.5
#                                            | GINI impurity of the node: 0.49
#                                            | Class distribution in the node: {1: 221, 0: 302}
#                                            | Predicted class: 0
# |------------------------------------------------ Split rule: age <= 54.5
#                                                    | GINI impurity of the node: 0.5
#                                                    | Class distribution in the node: {1: 188, 0: 221}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age <= 36.5
#                                                            | GINI impurity of the node: 0.29
#                                                            | Class distribution in the node: {0: 19, 1: 4}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 82.0
#                                                                    | GINI impurity of the node: 0.35
#                                                                    | Class distribution in the node: {0: 14, 1: 4}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week <= 77.5
#                                                                            | GINI impurity of the node: 0.22
#                                                                            | Class distribution in the node: {0: 14, 1: 2}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 71.0
#                                                                                    | GINI impurity of the node: 0.26
#                                                                                    | Class distribution in the node: {0: 11, 1: 2}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 71.0
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 3}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: hours-per-week > 77.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {1: 2}
#                                                                            | Predicted class: 1
# |---------------------------------------------------------------- Split rule: hours-per-week > 82.0
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {0: 5}
#                                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: age > 36.5
#                                                            | GINI impurity of the node: 0.5
#                                                            | Class distribution in the node: {1: 184, 0: 202}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week <= 80.5
#                                                                    | GINI impurity of the node: 0.5
#                                                                    | Class distribution in the node: {1: 143, 0: 143}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 39.5
#                                                                            | GINI impurity of the node: 0.48
#                                                                            | Class distribution in the node: {1: 27, 0: 39}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 67.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {1: 1}
#                                                                                    | Predicted class: 1
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 67.5
#                                                                                    | GINI impurity of the node: 0.48
#                                                                                    | Class distribution in the node: {1: 26, 0: 39}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 39.5
#                                                                            | GINI impurity of the node: 0.5
#                                                                            | Class distribution in the node: {1: 116, 0: 104}
#                                                                            | Predicted class: 1
# |-------------------------------------------------------------------------------- Split rule: age <= 43.5
#                                                                                    | GINI impurity of the node: 0.46
#                                                                                    | Class distribution in the node: {1: 41, 0: 23}
#                                                                                    | Predicted class: 1
# |-------------------------------------------------------------------------------- Split rule: age > 43.5
#                                                                                    | GINI impurity of the node: 0.5
#                                                                                    | Class distribution in the node: {1: 75, 0: 81}
#                                                                                    | Predicted class: 0
# |---------------------------------------------------------------- Split rule: hours-per-week > 80.5
#                                                                    | GINI impurity of the node: 0.48
#                                                                    | Class distribution in the node: {0: 59, 1: 41}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 39.5
#                                                                            | GINI impurity of the node: 0.5
#                                                                            | Class distribution in the node: {1: 14, 0: 13}
#                                                                            | Predicted class: 1
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 88.0
#                                                                                    | GINI impurity of the node: 0.2
#                                                                                    | Class distribution in the node: {0: 8, 1: 1}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 88.0
#                                                                                    | GINI impurity of the node: 0.4
#                                                                                    | Class distribution in the node: {1: 13, 0: 5}
#                                                                                    | Predicted class: 1
# |------------------------------------------------------------------------ Split rule: age > 39.5
#                                                                            | GINI impurity of the node: 0.47
#                                                                            | Class distribution in the node: {0: 46, 1: 27}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: age <= 53.5
#                                                                                    | GINI impurity of the node: 0.46
#                                                                                    | Class distribution in the node: {0: 46, 1: 26}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: age > 53.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {1: 1}
#                                                                                    | Predicted class: 1
# |------------------------------------------------ Split rule: age > 54.5
#                                                    | GINI impurity of the node: 0.41
#                                                    | Class distribution in the node: {0: 81, 1: 33}
#                                                    | Predicted class: 0
# |-------------------------------------------------------- Split rule: hours-per-week <= 98.5
#                                                            | GINI impurity of the node: 0.44
#                                                            | Class distribution in the node: {0: 65, 1: 31}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 87.0
#                                                                    | GINI impurity of the node: 0.43
#                                                                    | Class distribution in the node: {0: 65, 1: 30}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 70.5
#                                                                            | GINI impurity of the node: 0.45
#                                                                            | Class distribution in the node: {0: 58, 1: 30}
#                                                                            | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week <= 66.5
#                                                                                    | GINI impurity of the node: 0.0
#                                                                                    | Class distribution in the node: {0: 2}
#                                                                                    | Predicted class: 0
# |-------------------------------------------------------------------------------- Split rule: hours-per-week > 66.5
#                                                                                    | GINI impurity of the node: 0.45
#                                                                                    | Class distribution in the node: {0: 56, 1: 30}
#                                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 70.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 7}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 87.0
#                                                                    | GINI impurity of the node: 0.0
#                                                                    | Class distribution in the node: {1: 1}
#                                                                    | Predicted class: 1
# |-------------------------------------------------------- Split rule: hours-per-week > 98.5
#                                                            | GINI impurity of the node: 0.2
#                                                            | Class distribution in the node: {1: 2, 0: 16}
#                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age <= 72.5
#                                                                    | GINI impurity of the node: 0.12
#                                                                    | Class distribution in the node: {1: 1, 0: 15}
#                                                                    | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age <= 55.5
#                                                                            | GINI impurity of the node: 0.44
#                                                                            | Class distribution in the node: {1: 1, 0: 2}
#                                                                            | Predicted class: 0
# |------------------------------------------------------------------------ Split rule: age > 55.5
#                                                                            | GINI impurity of the node: 0.0
#                                                                            | Class distribution in the node: {0: 13}
#                                                                            | Predicted class: 0
# |---------------------------------------------------------------- Split rule: age > 72.5
#                                                                    | GINI impurity of the node: 0.5
#                                                                    | Class distribution in the node: {0: 1, 1: 1}
#                                                                    | Predicted class: 1

# %%
# Define the split value 
#age_split = 25 

# Ploting the original plot
plt.figure(figsize=(10, 10))
sns.scatterplot(y='hours-per-week', x='age', data=dtree, hue='yearly-income')
plt.grid()

# Adding the split line
plt.axhline(52.77, label='Best fare split', color='green')
plt.legend()
plt.show()

# %%
custom_tree_start = time.time()

# Initiating the Node
root = Node(Y, X, **hp)

# Getting teh best split
root.grow_tree()

custom_tree_time = time.time() - custom_tree_start
print(custom_tree_time)
# Out:
# 45.395949363708496

# %%
scikit_tree_start = time.time()

# Using the ML package 
clf = DecisionTreeClassifier(**hp)
clf.fit(X, Y)

scikit_tree_time = time.time() - scikit_tree_start

# %%
print(f"Custom tree growing time: {custom_tree_time}s")
print(f"Scikit tree growing time: {scikit_tree_time}s")
# Out:
# Custom tree growing time: 45.395949363708496s
# Scikit tree growing time: 0.10793137550354004s
